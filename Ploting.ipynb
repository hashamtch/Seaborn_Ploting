# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
dic = {"Name" :['Hasham','Haris','Akram'],
             "Age" : ['29','25','57'],
             "Profession": ['Data Analyst','Student','Bussinessman'],
             "Salary" : ['28000','26000','25000']
   }
df = pd.DataFrame(dic)
print(df)
# Out:
#      Name Age    Profession Salary
# 0  Hasham  29  Data Analyst  28000
# 1   Haris  25       Student  26000
# 2   Akram  57  Bussinessman  25000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        3 non-null      object
#  1   Age         3 non-null      object
#  2   Profession  3 non-null      object
#  3   Salary      3 non-null      object
# dtypes: object(4)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#           Name Age    Profession Salary
# count        3   3             3      3
# unique       3   3             3      3
# top     Hasham  29  Data Analyst  28000
# freq         1   1             1      1

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           0
# Profession    0
# Salary        0
# dtype: int64

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of      Name Age    Profession Salary
# 0  Hasham  29  Data Analyst  28000
# 1   Haris  25       Student  26000
# 2   Akram  57  Bussinessman  25000>

# %%
variable1 = [1,2,3,4,5]
variable2 = [6,7,8,9,10]
plt.plot(variable1,variable2)
plt.show()

# %%
import seaborn as sns
y1 = sns.load_dataset("titanic")
print(y1)

sns.lineplot(x = 'age', y = 'sex', data =y1 , hue ='class')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
